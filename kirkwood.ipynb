# %%
import rebound
import heyoka as hy
from tqdm import tqdm
from celmech import Poincare, PoincareHamiltonian
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
import symengine as se
import time

# %%
m_sat = 2.85837e-4
m_jup = 9.945786e-4
m_c = 1

def ft(times, x):
    fs = 1/((times[1] - times[0])/(2*np.pi))
    f, pxx = signal.periodogram(x,fs=fs,window='hann',scaling='density')
    return f,pxx

def pomega_ft(times,pomega,ecc):
    k = ecc*np.cos(pomega)
    h = ecc*np.sin(pomega)*1j
    z = h + k
    f,pxx = ft(times, z)
    return f,pxx

#from celmech docs
def get_pomega(kap,eta):
    return np.arctan2(-eta,kap)

def get_ecc(kap,eta,L):
    P = (kap**2 + eta**2)/2
    return np.sqrt(1 - (1 - P/L)**2)

# %%
sim = rebound.Simulation()
sim.add(m=1, hash = "Sun")
sim.add(m=1e-10,a=2.502,e=0.15,inc = 0, Omega = 0,l = 0, pomega=0,hash="test particle")
sim.add(m=m_jup,a=5.2,e=0.048,inc = 0,Omega = 0,l = np.pi,pomega=0,hash="Jupiter")

sim.move_to_com()

times = np.linspace(0,16e3*2*np.pi,int(1e3))*2*np.pi
e_ast = np.zeros(len(times))

for i in tqdm(range(len(times))):
    sim.integrate(times[i])
    e_ast[i] = sim.particles[1].e
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:06<00:00, 163.75it/s]

# %%
plt.plot(times/(2*np.pi)/11.86,e_ast)
plt.ylabel('Test Particle Eccentricity')
plt.xlabel("Time (Jupiter Orbits)")
plt.title('3:1 MMR Test Particle Eccentricity (Using IAS15) rebound')
plt.show()

# %%
sim = rebound.Simulation()
sim.add(m=1, hash = "Sun")
sim.add(m=1e-10,a=2.50,e=0.15,inc = 0, Omega = 0,l = 0, pomega=0,hash="test particle")
sim.add(m=m_jup,a=5.2,e=0.048,inc = 0,Omega = 0,l = np.pi,pomega=0,hash="Jupiter")

sim.move_to_com()

times = np.linspace(0,16e3*2*np.pi,int(1e3))*2*np.pi
e_ast = np.zeros(len(times))

for i in tqdm(range(len(times))):
    sim.integrate(times[i])
    e_ast[i] = sim.particles[1].e
plt.plot(times/(2*np.pi)/11.86,e_ast)
plt.ylabel('Test Particle Eccentricity')
plt.xlabel("Time (Jupiter Orbits)")
plt.title('3:1 MMR Test Particle Eccentricity (Using IAS15) rebound')
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:05<00:00, 178.54it/s]

# %%
sim = rebound.Simulation()
sim.add(m=1, hash = "Sun")
sim.add(m=1e-10,a=2.55,e=0.15,inc = 0, Omega = 0,l = 0, pomega=0,hash="test particle")
sim.add(m=m_jup,a=5.2,e=0.048,inc = 0,Omega = 0,l = np.pi,pomega=0,hash="Jupiter")

sim.move_to_com()

times = np.linspace(0,16e3*2*np.pi,int(1e3))*2*np.pi
e_ast = np.zeros(len(times))

for i in tqdm(range(len(times))):
    sim.integrate(times[i])
    e_ast[i] = sim.particles[1].e
plt.plot(times/(2*np.pi)/11.86,e_ast)
plt.ylabel('Test Particle Eccentricity')
plt.xlabel("Time (Jupiter Orbits)")
plt.title('3:1 MMR Test Particle Eccentricity (Using IAS15) rebound')
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:05<00:00, 188.35it/s]

# %%
sim = rebound.Simulation()
sim.add(m=1, hash = "Sun")
sim.add(m=1e-10,a=2.6,e=0.15,inc = 0, Omega = 0,l = 0, pomega=0,hash="test particle")
sim.add(m=m_jup,a=5.2,e=0.048,inc = 0,Omega = 0,l = np.pi,pomega=0,hash="Jupiter")

sim.move_to_com()

times = np.linspace(0,16e3*2*np.pi,int(1e3))*2*np.pi
e_ast = np.zeros(len(times))

for i in tqdm(range(len(times))):
    sim.integrate(times[i])
    e_ast[i] = sim.particles[1].e
plt.plot(times/(2*np.pi)/11.86,e_ast)
plt.ylabel('Test Particle Eccentricity')
plt.xlabel("Time (Jupiter Orbits)")
plt.title('3:1 MMR Test Particle Eccentricity (Using IAS15) rebound')
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:05<00:00, 192.12it/s]

# %%
sim = rebound.Simulation()
sim.add(m=1, hash = "Sun")
sim.add(m=1e-10,a=2.495,e=0.15,inc = 0, Omega = 0,l = 0, pomega=0,hash="test particle")
sim.add(m=m_jup,a=5.2,e=0.048,inc = 0,Omega = 0,l = np.pi,pomega=0,hash="Jupiter")

sim.move_to_com()

times = np.linspace(0,16e3*2*np.pi,int(1e3))*2*np.pi
e_ast = np.zeros(len(times))

for i in tqdm(range(len(times))):
    sim.integrate(times[i])
    e_ast[i] = sim.particles[1].e
plt.plot(times/(2*np.pi)/11.86,e_ast)
plt.ylabel('Test Particle Eccentricity')
plt.xlabel("Time (Jupiter Orbits)")
plt.title('3:1 MMR Test Particle Eccentricity (Using IAS15) rebound')
plt.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:05<00:00, 176.74it/s]

# %%
sim = rebound.Simulation()
sim.add(m=1, hash = "Sun")
sim.add(m=1e-10,a=2.49,e=0.15,inc = 0, Omega = 0,l = 0, pomega=0,hash="test particle")
sim.add(m=m_jup,a=5.2,e=0.048,inc = 0,Omega = 0,l = np.pi,pomega=0,hash="Jupiter")

sim.move_to_com()

times = np.linspace(0,16e3*2*np.pi,int(1e3))*2*np.pi
e_ast = np.zeros(len(times))

for i in tqdm(range(len(times))):
    sim.integrate(times[i])
    e_ast[i] = sim.particles[1].e
plt.plot(times/(2*np.pi)/11.86,e_ast)
plt.ylabel('Test Particle Eccentricity')
plt.xlabel("Time (Jupiter Orbits)")
plt.title('3:1 MMR Test Particle Eccentricity (Using IAS15) rebound')
plt.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:06<00:00, 162.38it/s]

# %%
sim = rebound.Simulation()
sim.add(m=1, hash = "Sun")
sim.add(m=1e-10,a=2.506,e=0.15,inc = 0, Omega = 0,l = 0, pomega=0,hash="test particle")
sim.add(m=m_jup,a=5.2,e=0.048,inc = 0,Omega = 0,l = np.pi,pomega=0,hash="Jupiter")

sim.move_to_com()

times = np.linspace(0,16e3*2*np.pi,int(1e3))*2*np.pi
e_ast = np.zeros(len(times))

for i in tqdm(range(len(times))):
    sim.integrate(times[i])
    e_ast[i] = sim.particles[1].e
plt.plot(times/(2*np.pi)/11.86,e_ast)
plt.ylabel('Test Particle Eccentricity')
plt.xlabel("Time (Jupiter Orbits)")
plt.title('3:1 MMR Test Particle Eccentricity (Using IAS15) rebound')
plt.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:08<00:00, 111.71it/s]
